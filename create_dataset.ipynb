# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/michaelford/Downloads/Crimes_-_2001_to_present (2).csv")
df = df[df['Primary Type'] == "THEFT"].copy()
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.shape
# Out:
# (1370731, 21)

# %%
df = df[df.Date < "2018-01-01"]

# %%
df = df[df['X Coordinate'].notnull()].copy()

# %%
 = df['Date'].copy()

# %%
df['Date'] = df['DateTime'].dt.date

# %%
df = df[df['District'].notnull()].copy()

# %%
df['Coursework Test Set'] = df['DateTime'] > "2016-01-01"

# %%
df.to_csv("chicago_crime_thefts_filtered_v2.csv")

# %%
df.head()
# Out:
#          Case Number        Date                     Block  IUCR Primary Type  \
# ID
# 10000111    HY190019  2015-03-18       051XX W CHICAGO AVE  0860        THEFT
# 10000115    HY190036  2015-03-18       069XX S LOOMIS BLVD  0890        THEFT
# 10000117    HY190068  2015-03-18       087XX S KIMBARK AVE  0890        THEFT
# 10000118    HY190031  2015-03-18  075XX S STONY ISLAND AVE  0860        THEFT
# 10000190    HY190026  2015-03-18       035XX W CARROLL AVE  0810        THEFT
#
#             Description Location Description  Arrest  Domestic  Beat  \
# ID
# 10000111   RETAIL THEFT          GAS STATION    True     False  1531
# 10000115  FROM BUILDING   GROCERY FOOD STORE   False     False   734
# 10000117  FROM BUILDING        BAR OR TAVERN   False     False   412
# 10000118   RETAIL THEFT   GROCERY FOOD STORE    True     False   411
# 10000190      OVER $500                OTHER   False      True  1123
#
# ...
